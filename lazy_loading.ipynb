# %%
import polars as pl

df: pl.DataFrame = pl.scan_csv("./ecommerce_dataset/2019-Nov.csv")

a = df.head(1000000).lazy()
print(a)

a.collect()
# Out:
# naive plan: (run LazyFrame.explain(optimized=True) to see the optimized plan)
#
# SLICE[offset: 0, len: 1000000]
#   Csv SCAN [./ecommerce_dataset/2019-Nov.csv]
#   PROJECT */9 COLUMNS
#   ESTIMATED ROWS: 63877747

# %%
import polars as pl

df: pl.DataFrame = pl.read_csv("./ecommerce_dataset/2019-Nov.csv")

a = df.head(1000000).lazy()

a.collect(streaming=True)
# Out:
# /var/folders/8z/0cycb4ss5v52k0fk3sdsbyr80000gp/T/ipykernel_46301/3075151718.py:7: DeprecationWarning: the `streaming` parameter was deprecated in 1.25.0; use `engine` instead.
#   a.collect(streaming=True)
# shape: (1_000_000, 9)
# ┌────────────┬────────────┬────────────┬────────────┬───┬─────────┬────────┬───────────┬───────────┐
# │ event_time ┆ event_type ┆ product_id ┆ category_i ┆ … ┆ brand   ┆ price  ┆ user_id   ┆ user_sess │
# │ ---        ┆ ---        ┆ ---        ┆ d          ┆   ┆ ---     ┆ ---    ┆ ---       ┆ ion       │
# │ str        ┆ str        ┆ i64        ┆ ---        ┆   ┆ str     ┆ f64    ┆ i64       ┆ ---       │
# │            ┆            ┆            ┆ i64        ┆   ┆         ┆        ┆           ┆ str       │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪═════════╪════════╪═══════════╪═══════════╡
# │ 2019-11-01 ┆ view       ┆ 1003461    ┆ 2053013555 ┆ … ┆ xiaomi  ┆ 489.07 ┆ 520088904 ┆ 4d3b30da- │
# ...
